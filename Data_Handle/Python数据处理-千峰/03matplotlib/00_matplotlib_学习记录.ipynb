# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 一 matplotlib 基础

# %%
# 可以使用多个plot函数, 在一个图中绘制多个曲线(推荐)
x = np.linspace(1, 10, 10)
plt.plot(x)
plt.plot(x, x ** 2)
plt.show()

# %%
# 也可以在一个plot函数中传入多对x, y值, 在一个图中绘制多个曲线
x = np.arange(0, 10, 1)
plt.plot(x, x ** 2, x, 5 * x, x, x / 3)
plt.grid(True)  # 添加网格线
plt.show()

# %%
# 绘制正弦曲线
# lw代表linewidth, 线的粗细
# alpha表示线的明暗程度(0-1)
# color表示线的颜色
x = np.arange(-np.pi, np.pi, 0.01)
plt.plot(x, np.sin(x), x, np.cos(x), lw=10, alpha=0.5, color="blue")
plt.grid(True)
plt.show()

# %% [markdown]
# # 二 面向对象与设置标题

# %% [markdown]
# ### plt面向对象, 图形就是所谓的对象

# %%
# 设置整张图片的大小
plt.figure(figsize=(5, 3))

x1 = np.linspace(-np.pi, np.pi, 100)
plt.plot(x1, np.sin(x1))
# loc值: 'center', 'right', 'left'
plt.title("f(x) = sin(x)", fontsize=20, loc="right")
plt.show()

# %%
# 设置整张图片的大小
plt.figure(figsize=(10, 7))

x1 = np.arange(-10, 10, 0.1)
# 图片显示的位置subplot(m行, n列, local最大值为m*n
axes1 = plt.subplot(2, 3, 1)
# 设置网格线的颜色, 线条的格式, 线条的宽度
axes1.grid(color="r", linestyle="-.", linewidth=2)
# 设置图片1标题字体大小与格式
axes1.set_title('sin', fontsize='large', fontweight='bold') 
axes1.plot(x1, np.sin(x1))

axes2 = plt.subplot(2, 3, 2)
x2 = np.arange(-10, 10, 0.1)
axes2.grid(color="g", linestyle="--", linewidth=1)
axes2.set_title('cos', fontsize='large', fontweight='bold')  
axes2.plot(x2, np.cos(x2))

axes3 = plt.subplot(2, 3, 3)
x3 = np.arange(-10, 10, 0.1)
axes3.grid(color="b", linestyle="-.", linewidth=1)
axes3.set_title('y = x ** 2', fontsize='large', fontweight='bold')  
axes3.plot(x3, x3 ** 2)

axes4 = plt.subplot(2, 3, 5)
x4 = np.arange(-10, 10, 2)
axes4.grid(color="gray", linestyle="-.", linewidth=1)
axes4.set_title('y = 4x + 1', fontsize='large', fontweight='bold')
axes4.set_facecolor("g")  # 设置背景颜色
axes4.plot(x4, 4 * x4 + 1, "w>--", lw = 7)

# 设置整张图片的图片名字
plt.suptitle('Picture', fontsize='large', fontweight='bold')

plt.show()

# %% [markdown]
# # 三 坐标轴界限

# %% [markdown]
# ### 3-1 axis 方法:  tight(默认), off, equal, square

# %%
# 设置整张图片的大小
plt.figure(figsize=(5, 3))
ax = plt.subplot(1, 2, 1)

# axis square/将当前坐标系图形设置为方形。横轴及纵轴比例是1：1
# axis equal/将横轴纵轴的定标系数设成相同值。
# 如果axis方法没有任何参数, 则返回当前坐标轴的上下限, axis(xmin=, ymax=)
x1 = np.random.rand(10)
ax.plot(x1)
ax.axis([-5, 15, -5, 10])  # [xmin, xmax, ymin, ymax]
ax.axis("off")  # 关闭坐标轴

ax2 = plt.subplot(1, 2, 2)
x2 = np.linspace(-np.pi, np.pi, 100)
ax2.plot(np.sin(x2), np.cos(x2))
ax2.axis("equal")  # 将横轴纵轴的定标系数设成相同值
ax2.axis("off")  # 关闭坐标轴
plt.show()

# %% [markdown]
# ### 3-2 xlim方法与ylim方法

# %%
plt.figure(figsize=(5, 3))
# xlim方法与ylim方法
y = np.arange(0, 10, 1)
plt.plot(y)

plt.ylim(2, 10)  # 从2开始到10结束
plt.xlim(4, 8)  # 从4开始到8结束
plt.show()

# %% [markdown]
# ### 3-3 坐标轴标签  xlabel方法和ylable方法

# %%
ax4 = plt.subplot(1, 2, 2)
x = np.arange(-5, 5, 0.1)
y = x ** 2 + 5
ax4.plot(x, y)

# horizontalalignment值: 'center', 'right', 'left'
plt.ylabel("f(x) = x**2 + 5", horizontalalignment="left")
# verticalalignment值: 'top', 'bottom', 'center', 'baseline', 'center_baseline'
# rotation表示倾斜角度
plt.xlabel("this is x", size=10, rotation=0, verticalalignment="top")
plt.show()

# %% [markdown]
# # 四 图例

# %% [markdown]
# ### 4-1 legend

# %%
"""图例(legend方法)
两种传参方法:
1. 在plot函数中增加label参数(推荐)
2. 在legend方法中传入字符串列表
"""
plt.figure(figsize=(10, 4))  # 设置整张图片的大小

# 方法一
ax1 = plt.subplot(1, 3, 1)
ax1.set_title("first")
x1 = np.arange(0, 10, 1)
ax1.plot(x1, x1, label="normal")
ax1.plot(x1, x1 ** 2, label="_fast")  # label添加下划线_, 被隐藏
ax1.plot(x1, x1 / 2, label="slow")
"""loc 位置值 
'best': 0,         'upper right': 1,    'upper left': 2,
'lower left': 3,   'lower right': 4,    'right': 5, 
'center left': 6,  'center right': 7,   'lower center': 8,
'upper center': 9, 'center': 10,
"""
ax1.legend()
# ax3.legend(loc="right")
# ax3.legend(loc=(-0.2, 1))
# ax3.legend(loc=(0.5, 1))
# ax1.legend(loc=(1, 0))

# 方法二
ax2 = plt.subplot(1, 3, 2)
ax2.set_title("second")
x2 = np.arange(0, 10, 1)
ax2.plot(x2, x2, x2, x2 * 2, x2, x2 / 2)
ax2.legend(["normal", "fast", "slow"])

# ncol 参数: 每一行显示几个
ax3 = plt.subplot(1, 3, 3)
ax3.set_title("third")
x3 = np.arange(0, 10, 1)
ax3.plot(x3, x3, "r", x3, x3 * 2, "g", x3, x3 / 2, "b>--")
ax3.legend(["normal", "fast", "slow"], loc = 0, ncol = 2)
plt.show()

# %% [markdown]
# ### 4-2 线条的颜色color, 格式linestyle, 标记marker

# %%
plt.figure(figsize=(8, 4))
x1 = np.random.randn(20)
x2 = np.random.randn(20)
x3 = np.random.randn(20)
plt.plot(x1.cumsum(), color = "red", linestyle = "--", marker = "o")
plt.plot(x2.cumsum(), color = "yellow", linestyle = "-.", marker = ">")
plt.plot(x3.cumsum(), color = "purple", linestyle = ":", marker = "|")
plt.legend(["x1", "x2", "x3"])
plt.show()

# %% [markdown]
# # 五 保存图片

# %% [markdown]
# #### figure.savefig 的选项

# %% [raw]
# filename 含有文件路径的字符串或 Python 的文件类型对象. 图像格式由文件扩展名推断得出, 例如: .pdf推断出PDF, .png 推断出PNG("png" "pdf", "svg", "ps", "eps")

# %% [raw]
# dpi 图像分辨率(每英寸点数), 默认为100

# %%
plt.figure(figsize=(8, 4))
x1 = np.random.randn(20)
x2 = np.random.randn(20)
x3 = np.random.randn(20)
plt.plot(x1.cumsum(), color = "red", linestyle = "--", marker = "o")
plt.plot(x2.cumsum(), color = "yellow", linestyle = "-.", marker = ">")
plt.plot(x3.cumsum(), color = "purple", linestyle = ":", marker = "|")
plt.legend(["x1", "x2", "x3"])
# plt.savefig(fname = "../../Picture/test.png", dpi = 500)
plt.savefig(fname = "../../Picture/test.png", dpi = 500, facecolor = "b", edgecolor='g')

# %% [markdown]
# # 五　设置 plot 的风格和样式

# %% [markdown]
# ### 5-1 颜色设置

# %% [markdown]
#     jpg png 区别, 格式不同, 数据存储也不同, png:归一化的红绿蓝数据, jpg:0~255数据

# %%
x = np.arange(0, 10, 0.1)
# 方法一
# plt.plot(x, np.sin(x), color = "red")
# 方法二: HTML十六制字符串
# plt.plot(x, np.sin(x), color = "#ffff00")
# 方法三: 归一化到[0, 1]的RGB元组
plt.plot(x, np.sin(x), color = (0.3, 0.3, 0.4))
plt.show()

# %% [markdown]
# ### 5-2 alpha 透明度 (0-1)

# %%
x = np.arange(1, 10, 0.1)
# 十六进制表示颜色: 8位前两位是透明度
# 只能使用6位进行表示, 红绿蓝
plt.plot(x, np.sin(x), "#ff0000", alpha = 0.5)
plt.show()

# %% [markdown]
# ### 5-2 背景色

# %% [markdown]
#     设置背景色, 通过 plt.subplot() 方法传入 facecolor 参数, 来设置坐标轴的背景色

# %%
x = np.arange(0, 10, 0.1)
# 面向对象画图方法, 生成 axes 画板 
axes = plt.subplot(facecolor = "green")
axes.plot(x, np.sin(x), color = 'w', linestyle = "steps", linewidth = 1)

# %% [markdown]
# ### 5-3 多个不同曲线不同设置

# %%
# fmt = '[color][marker][line]'
x = np.arange(0, 10, 1)
plt.plot(x, x, "r|--", x, np.cos(x), "g>--", markersize = 15)

# %% [markdown]
# ### 5-4 setp 方法

# %%
x = np.arange(0, 10, 0.4)
# plot函数返回的是一个列表,因为可以同时画多条线
line1, line2 = plt.plot(x, np.sin(x), x, x / 2)
# linestyle: [ '-' | '--' | '-.' | ':' | 'steps' | 'None' ]
plt.setp(line1, linestyle = "steps", linewidth = 1, marker = "o", markersize = 10)
plt.setp(line2, linestyle = "-.", linewidth = 2, marker = "|", markersize = 30)
# Out:
# [None, None, None, None]

# %% [markdown]
# ### 5-5 xticks与yticks 设置x轴与y轴刻度及标签

# %% [markdown]
# #### xticks 设置 X 轴的刻度，其中 minor=True 参数表示设置更小的刻度；
# #### yticks 设置 Y 轴的刻度；
# #### xlabel 设置 X 轴的标签；ylabel 设置 Y 轴的标签；
# #### 设置x轴刻度的  1.步长ticks  2.标签labels  3.字体大小fontsize  4.旋转角度 rotation

# %%
x = np.random.randn(5)
plt.plot(x.cumsum())
plt.xticks(ticks = np.arange(5), labels = ["A", "B", "C"], fontsize = 10)  # 设置x轴的刻度
# np.linspace(-1, 5, 3)表示(-1, 5)的区间分成三份
plt.yticks(ticks = np.linspace(-1, 5, 3), labels = ["min", 0, "max"], fontsize = 20)
plt.show()

# %%
x = np.random.randn(100)
plt.plot(x.cumsum())
plt.xticks(np.linspace(0, 100, 5), ["A", "B", "C", "D", "E"])
plt.show()

# %%
plt.figure(figsize=(15, 5))
x = np.arange(-20, 21, 1)
plt.plot(x, x ** 2)
plt.xticks(ticks = range(-20, 20, 1), rotation = 90)
plt.yticks(ticks = np.linspace(0, 400, 8), labels = ["A", "B", "C", "D", "E", "F", "G", "H"], rotation = 0)
plt.show()

# %% [markdown]
# #### 面向对象的方式

# %% [markdown]
# set_xticks, set_yticks, set_xticklabels, set_yticklabels方法

# %%
plt.figure(figsize = (10, 5))

axes = plt.subplot(1, 2, 1)
x = np.arange(-10, 11, 1)
axes.plot(x, x ** 2)
axes.set_xticks(np.arange(-10, 11, 5))
axes.set_xticklabels(["A", "B", "C", "D", "E"], rotation = 90)
axes.set_yticks([0, 50, 100])
axes.set_yticklabels(["min", 0, "max"])

axes2 = plt.subplot(1, 2, 2)
x2 = np.arange(-10, 11, 1)
axes2.plot(x2, x2 ** 2)
axes2.set_xticks(np.arange(-10, 11, 5))
axes2.set_xticklabels(["a", "b", "c", "d", "e"], rotation = 90)
axes2.set_yticks([0, 50, 100])
axes2.set_yticklabels(["wa", "ha", "ha"])
plt.show()

# %%
x = np.arange(-np.pi, np.pi, 0.1) # x的长度为63
plt.plot(np.sin(x))
# plt.xticks([0, len(x)/5 , 2*(len(x)/5), 3*(len(x)/5), 4*(len(x)/5), 5*(len(x)/5)])
plt.xticks([0, 12.6, 25.2, 37.8, 50.4, 63.0], ["-$\pi$", "-$\pi/2$", 0, "$\pi/2$", "$\pi$", "$3\pi/2$"])
plt.show()

# %% [markdown]
# # 六 2D 图形

# %% [markdown]
# #### 6-1 直方图 hist -- 直方图的参数只有一个x, 不像条形图需要传入x, y

# %% [raw]
# hist() 的参数
# bins    可以是一个 bin 数量的整数值, 也可以是表示 bin 的一个序列, 默认值为10.
# density 如果值为 True 是频率图，默认是 False 频数图
# color   指定直方图的颜色, 可以是单一颜色值或颜色的序列, 如果制定了多个数据集合,
#         颜色序列将会设置为相同的顺序, 如果未指定, 将会使用一个默认的线条颜色.
# orientation 通过设置 orientation 为 horizontal 创建水平直方图, 默认为 vertical.

# %%
x = np.random.randint(0, 10, 10)
x = np.array([8, 2, 1, 7, 2, 6, 2, 3, 2, 8])
plt.hist(x, density = False, orientation = "vertical", color = "g")
plt.show()

# %% [markdown]
# #### 6-2 条形图 bar  --  条形图有两个参数 x, y

# %%
x = np.linspace(0, 5, 5)
y = np.random.randint(0, 20, size=5)
plt.bar(x, y)
plt.show()

# %% [markdown]
# ### 6-3 饼图 pie -- 只有一个参数 x

# %% [markdown]
# ##### 6-3-1 占满饼图与未占满饼图

# %%
# autopct 在饼图中显示占比, 并设置占比格式
# labeldistance 标签距离圆心的距离
# pctdistance 比例值文字距离圆心的距离
# explode 设置饼图每一块区域距离圆心的距离
# colors 设置每一块饼图的颜色
# startangle 设置旋转的角度

plt.figure(figsize = (10, 10))

ax1 = plt.subplot(3, 2, 1)
p1 = np.array([0.7, 0.2, 0.1])
ax1.pie(p1, labels = ["dog", "cat", "other"], autopct = "%1.2f%%", labeldistance = 0.9)
ax1.axis("equal")  # 使饼图边圆一点
ax1.set_title("Fill")

ax2 = plt.subplot(3, 2, 2)
p2 = np.array([0.5, 0.2, 0.1])
ax2.pie(p2, labels = ["dog", "cat", "other"], autopct = "%1.2f%%", pctdistance = 0.8, labeldistance = 1)
ax2.axis("equal")
ax2.set_title("Miss")

ax3 = plt.subplot(3, 2, 3)
p3 = np.array([0.7, 0.2, 0.1])
ax3.pie(p3, labels = ["dog", "cat", "other"], explode = [0, 0.1, 0.3])
ax3.axis("equal")
ax3.set_title("explode")

ax4 = plt.subplot(3, 2, 4)
p4 = np.array([0.7, 0.2, 0.1])
ax4.pie(p4, labels = ["dog", "cat", "other"], colors = ["gray", "g", "pink"])
ax4.axis("equal")
ax4.set_title("colors")

ax5 = plt.subplot(3, 2, 5)
p5 = np.array([0.7, 0.2, 0.1])
ax5.pie(p5, labels = ["dog", "cat", "other"], shadow = True, explode = [0, 0.1, 0.3])
ax5.axis("equal")
ax5.set_title("shadow")

ax6 = plt.subplot(3, 2, 6)
p6 = np.array([0.7, 0.2, 0.1])
ax6.pie(p6, labels = ["dog", "cat", "other"], startangle = 90)
ax6.axis("equal")
ax6.set_title("startangle")

plt.suptitle("Fill and Miss")
plt.show()

# %% [markdown]
# ### 6-4 散点图 scatter

# %%
x = np.random.randn(1000)
y = np.random.randn(1000)
colors = np.random.random(3000).reshape((1000, 3)) # 设置随机颜色值
size = np.random.randint(0, 100, 1000)
plt.scatter(x, y, color = colors, s = size, marker = "D")
plt.show()

# %%
color1 = np.random.random(9).reshape((3, 3))
color2 = color1.reshape((9, 1))
print(color1)
print("----")
print(color2)
# Out:
# [[0.67784251 0.99631403 0.88184232]
#  [0.90008747 0.80344115 0.21829391]
#  [0.60878937 0.10938797 0.72177463]]
# ----
# [[0.67784251]
#  [0.99631403]
#  [0.88184232]
#  [0.90008747]
#  [0.80344115]
#  [0.21829391]
#  [0.60878937]
#  [0.10938797]
#  [0.72177463]]

# %%
plt.figure(figsize=(20,5))
size = np.random.randint(0, 100, 1000)
plt.hist(size)
plt.xticks(range(0, 100, 1), rotation = 90)
plt.show()

# %% [markdown]
# # 七 图形内的文字, 注释, 箭头

# %% [markdown]
#  Pyplot 函数  |   API 方法    |      描述
# :-------------|:-------------:|-------------:
# text()        |  mpl.axes.Axes.text() |  在 Axes 对象的任意位置添加文字
# xlabel()      |  mpl.axes.Axes.set_xlabel() |  为 x 轴添加标签
# ylabel()      |  mpl.axes.Axes.set_ylabel() |  为 y 轴添加标签
# title()       |  mpl.axes.Axes.set_title() |  为 Axes 对象添加标题
# legend()      |  mpl.axes.Axes.legend() |  为 Axes 对象添加图例
# figtext()     |  mpl.figure.Figure.text() |  在 Figure 对象的任意位置添加文字
# suptitle() |  mpl.figure.Figure.suptitle() |  为 Figure 对象的添加中心化的标题
# annnotate() | mpl.axes.Axes.annnotate() | 为 Axes 对象添加注释(箭头可选)
# ||所有的方法会返回一个 matplotlib.text.Text 对象
#
# #### 7-1 向图形内添加文字 text

# %%
x = np.arange(0, 2 * np.pi, 0.1)
picture = plt.plot(x, np.sin(x))
# text 中的x与y表示坐标轴上面的坐标
plt.text(x=i, y=np.sin(i), s="sin(%1.2f)=%1.2f" % (i, np.sin(i)))
plt.show(picture)

# %%
x = np.arange(0, 2 * np.pi, 0.1)
plt.plot(x, np.sin(x))
# figtext 中的x与y表示相对值, 图片的宽高
plt.figtext(x=0.5, y=0.5, s="sin(%1.2f)=%1.2f" % (0.5, np.sin(0.5)))
plt.show()

# %% [markdown]
# ### 7-2 注释

# %%
x = np.random.randint(0, 20, size=10)
x[5] = 30
plt.plot(x)
plt.ylim(0, 35)
plt.xlim(0, 15)
# s 表示要写的文本字体
# xy 表示箭头的坐标
# xytext 表示文本的坐标位置
# plt.annotate(text="this point is important!", xy=(5, 30), xytext=(7, 31), arrowprops = {"width": 10, "headwidth":20, "headlength":10, "shrink":0.1})
plt.annotate(text="this point is important!", xy=(5, 30), xytext=(7, 31), arrowprops = {"arrowstyle":"->"})
plt.show()

# %% [markdown]
# ### 7-3 箭头的样式

# %%
plt.figure(figsize=(12, 6))
plt.axis([0, 9, 0, 16])
arrstyles = ["-", "->", "<-", "<->", "fancy", "simple", "wedge"]
for i, style in enumerate(arrstyles):
    plt.annotate(style, xytext=(1, 2+2*i), xy=(4, 1+2*i), arrowprops = dict(arrowstyle = style))

connstyles = ["arc", "arc, angleA=10, armA=30, rad=30", "arc3, rad=.2", "arc3, rad=-.2", "angle", "angle3"]
for i, style in enumerate(connstyles):
    plt.annotate(style, xytext=(6, 2+2*i), xy=(8, 1+2*i), arrowprops = dict(arrowstyle = "->", connectionstyle=style))

plt.show()

# %% [markdown]
# ### 7-4 练习

# %%
x1 = np.random.normal(10, 1, 100)
x2 = np.random.normal(20, 1, 100)
x3 = np.random.normal(30, 1, 100)
plt.plot(x1, label = "plot")
plt.plot(x2, label = "2nd plot")
plt.plot(x3, label = "last plot")
plt.ylim(0, 35)
plt.annotate(text="this point is important!", xy=(60, 20), xytext=(0, 33), arrowprops = {"arrowstyle":"->"})
# plt.legend(ncol=3, mode = "expand", loc=(0.02, 1.02))
# (x, y, width, height)
plt.legend(ncol=3, mode = "expand", bbox_to_anchor = (0, 1.02, 1, 0.1))
plt.show()

# %% [markdown]
# # 八 3D图形

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
x = np.arange(0, 7, 0.01)
y = np.arange(-3.5, 3.5, 0.01)

X, Y = np.meshgrid(x, y) # 将两个一维数组变为二维矩阵

def mk_z(X, Y):
    return 3 + 0.5 * np.sin(X) * np.cos(Y) - np.cos(2-X)

Z = mk_z(X, Y)

# %%
fig = plt.figure(figsize=(5, 5))
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z)
plt.show()
